# %%
# %matplotlib inline

from hirexsr_get_profile_py import hirexsr_get_profile_py, _plot_profile_vs_lint
from hirexsr_lint_profile_py import hirexsr_get_lint_profile_py, _plot_lint_profile

shot = 1140221012
line = 7
out = hirexsr_get_profile_py(
        shot=shot,
        line=line,
        dc_shift=0,
        tht=0,
        override=False,
        seltime=None,
    )

lint = hirexsr_get_lint_profile_py(
    shot=shot,
    line=line,
    tht=0,
    use_idl_profile_moments=False,
)

# _plot_inversion_profile(
#             out,
#             tht=0,
#             every_nth=30,
#             x_axis='psi',
#             w_limit=10000,
#             emiss_lim=50,
#             Ti_limit=1000,
#             doSave='',
#             specific_timepoint=1.003,
#         )

_plot_profile_vs_lint(
    prof=out,
    lint=lint,
    tht=0,
    x_axis='psi',
    every_nth=10,
    doSave='',
    v_lims=(-40,40),
    emiss_lims=(0,5),
    ti_lims=(0,5),
    specific_timepoint=[0.5, 1, 1.5],
)
# Out:
# Loaded inversion profile: shot=1140221012, line=z, nt=51, npsi=16
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=5250/12000, non-unity=5250, range=[8.744e-01, 1.025e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 51 out of 125 total

# %%
# Data quality scanning has been moved to hirexsr_data_quality.py
# Run from a terminal:
#
#   python hirexsr_data_quality.py \
#       --csv cmod_logbook_ntm_shots.csv \
#       --mode both \
#       --lint-out hirexsr_lint_quality.json \
#       --profile-out hirexsr_profile_quality.json \
#       --min-timepoints 5 --min-channels 5
#
# Optional error-bar thresholds (add any combination):
#       --max-verr-abs 50      # absolute velocity error limit [km/s or kHz]
#       --max-verr-rel 0.5     # relative velocity error limit |err|/|v|
#       --max-tierr-abs 2.0    # absolute Ti error limit [keV]
#       --max-tierr-rel 0.5    # relative Ti error limit |tierr|/Ti
#
# Or call the scan functions directly from Python:

# These functions take a while to run, so they will be commented out by default, but if you need to batch run 
# a large number of shots to check their validity, uncomment the below

# import numpy as np
# from hirexsr_data_quality import scan_lint_quality, scan_profile_quality, _build_output_dict
# import json
# file_name = 'blessed_profiles'

# shots_list = np.sort( np.loadtxt(f'{file_name}.csv', dtype=int, delimiter=',').flatten() ).tolist()
# print(shots_list)
# # Example: scan with default quality gates (5 timepoints, 5 channels, no error threshold)
# lint_results = scan_lint_quality(shots_list, min_timepoints=5, min_channels=5)
# prof_results = scan_profile_quality(shots_list, min_timepoints=5, min_channels=5)

# with open(f"hirexsr_{file_name}_lint_quality.json", "w") as f:
#     json.dump(_build_output_dict(lint_results), f, indent=4, sort_keys=True, ensure_ascii=False)

# with open(f"hirexsr_{file_name}_profile_quality.json", "w") as f:
#     json.dump(_build_output_dict(prof_results), f, indent=4, sort_keys=True, ensure_ascii=False)

# print(f"Saved hirexsr_{file_name}_lint_quality.json and hirexsr_{file_name}_profile_quality.json")
# Out:
# [1080312014, 1080502015, 1080522007, 1100305019, 1101014006, 1101014019, 1101014029, 1101014030, 1110114009, 1110114010, 1110114014, 1110114014, 1110114018, 1110114019, 1110114020, 1110114020, 1110114021, 1110114021, 1110114032, 1110114032, 1120106012, 1120106016, 1120816010, 1120816011, 1120816013, 1120829027, 1120906020, 1120907005, 1120912027, 1120913010, 1120913018, 1120914029, 1120914036, 1120917011, 1120917021, 1121001018, 1140221012, 1140729021, 1140729023, 1140729030, 1160506007, 1160506008, 1160506024, 1160708013, 1160708015, 1160708024, 1160713014, 1160714032, 1160718023, 1160721019, 1160729005, 1160729008, 1160922007, 1220221008, 1220221009, 1220221010, 1220221011, 1220221012]
#   lint    1080312014  (none)
#   lint    1080502015  (none)
#   lint    1080522007  (none)
# Loaded moments data: mom shape=(3, 250, 32), err shape=(3, 250, 32), pos shape=(32, 4)
# Extracted tau shape=(250,), rhotang shape=(250, 32)
# Computed emiss shape=(250, 32), emisserr shape=(250, 32), v shape=(250, 32), verr shape=(250, 32), ti shape=(250, 32), tierr shape=(250, 32)
# Geom stats: finite=4250/8000, non-unity=4250, range=[8.140e-01, 8.209e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 26 out of 250 total
# Loaded moments data: mom shape=(3, 250, 32), err shape=(3, 250, 32), pos shape=(32, 4)
# Extracted tau shape=(250,), rhotang shape=(250, 32)
# Computed emiss shape=(250, 32), emisserr shape=(250, 32), v shape=(250, 32), verr shape=(250, 32), ti shape=(250, 32), tierr shape=(250, 32)
# Geom stats: finite=4250/8000, non-unity=4250, range=[8.140e-01, 8.209e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 26 out of 250 total
# Loaded moments data: mom shape=(3, 250, 32), err shape=(3, 250, 32), pos shape=(32, 4)
# Extracted tau shape=(250,), rhotang shape=(250, 32)
# Computed emiss shape=(250, 32), emisserr shape=(250, 32), v shape=(250, 32), verr shape=(250, 32), ti shape=(250, 32), tierr shape=(250, 32)
# Geom stats: finite=4250/8000, non-unity=4250, range=[8.140e-01, 8.209e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 26 out of 250 total
#   lint    1100305019  3:hlike.lya1, 6:hlike.lya1, 9:hlike.lya1
# /mnt/home/rianc/Documents/HIREXSR_py/hirexsr_lint_profile_py.py:768: RuntimeWarning: invalid value encountered in divide
#   v_nogeom = (mom1 / mom0) * c / lam_o * 1.0e-3
# /mnt/home/rianc/Documents/HIREXSR_py/hirexsr_lint_profile_py.py:776: RuntimeWarning: invalid value encountered in divide
#   ti = (mom2 / mom0) / conv_factor
# Loaded moments data: mom shape=(3, 417, 96), err shape=(3, 417, 96), pos shape=(96, 4)
# Extracted tau shape=(417,), rhotang shape=(417, 96)
# Computed emiss shape=(417, 96), emisserr shape=(417, 96), v shape=(417, 96), verr shape=(417, 96), ti shape=(417, 96), tierr shape=(417, 96)
# Geom stats: finite=20016/40032, non-unity=20016, range=[7.295e-01, 8.843e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 167 out of 417 total
# Loaded moments data: mom shape=(3, 417, 96), err shape=(3, 417, 96), pos shape=(96, 4)
# Extracted tau shape=(417,), rhotang shape=(417, 96)
# Computed emiss shape=(417, 96), emisserr shape=(417, 96), v shape=(417, 96), verr shape=(417, 96), ti shape=(417, 96), tierr shape=(417, 96)
# Geom stats: finite=20016/40032, non-unity=20016, range=[7.794e-01, 9.554e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 167 out of 417 total
# Loaded moments data: mom shape=(3, 417, 96), err shape=(3, 417, 96), pos shape=(96, 4)
# Extracted tau shape=(417,), rhotang shape=(417, 96)
# Computed emiss shape=(417, 96), emisserr shape=(417, 96), v shape=(417, 96), verr shape=(417, 96), ti shape=(417, 96), tierr shape=(417, 96)
# Geom stats: finite=20016/40032, non-unity=20016, range=[8.804e-01, 1.110e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 167 out of 417 total
# Loaded moments data: mom shape=(3, 417, 32), err shape=(3, 417, 32), pos shape=(32, 4)
# Extracted tau shape=(417,), rhotang shape=(417, 32)
# Computed emiss shape=(417, 32), emisserr shape=(417, 32), v shape=(417, 32), verr shape=(417, 32), ti shape=(417, 32), tierr shape=(417, 32)
# Geom stats: finite=13344/13344, non-unity=13344, range=[8.230e-01, 8.316e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 167 out of 417 total
# Loaded moments data: mom shape=(3, 417, 32), err shape=(3, 417, 32), pos shape=(32, 4)
# Extracted tau shape=(417,), rhotang shape=(417, 32)
# Computed emiss shape=(417, 32), emisserr shape=(417, 32), v shape=(417, 32), verr shape=(417, 32), ti shape=(417, 32), tierr shape=(417, 32)
# Geom stats: finite=13344/13344, non-unity=13344, range=[8.230e-01, 8.316e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 167 out of 417 total
# Loaded moments data: mom shape=(3, 417, 96), err shape=(3, 417, 96), pos shape=(96, 4)
# Extracted tau shape=(417,), rhotang shape=(417, 96)
# Computed emiss shape=(417, 96), emisserr shape=(417, 96), v shape=(417, 96), verr shape=(417, 96), ti shape=(417, 96), tierr shape=(417, 96)
# Geom stats: finite=20016/40032, non-unity=20016, range=[8.804e-01, 1.110e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 167 out of 417 total
# Loaded moments data: mom shape=(3, 417, 96), err shape=(3, 417, 96), pos shape=(96, 4)
# Extracted tau shape=(417,), rhotang shape=(417, 96)
# Computed emiss shape=(417, 96), emisserr shape=(417, 96), v shape=(417, 96), verr shape=(417, 96), ti shape=(417, 96), tierr shape=(417, 96)
# Geom stats: finite=20016/40032, non-unity=20016, range=[7.794e-01, 9.554e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 167 out of 417 total
# Loaded moments data: mom shape=(3, 417, 32), err shape=(3, 417, 32), pos shape=(32, 4)
# Extracted tau shape=(417,), rhotang shape=(417, 32)
# Computed emiss shape=(417, 32), emisserr shape=(417, 32), v shape=(417, 32), verr shape=(417, 32), ti shape=(417, 32), tierr shape=(417, 32)
# Geom stats: finite=13344/13344, non-unity=13344, range=[8.230e-01, 8.316e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 167 out of 417 total
#   lint    1101014006  0:helike.w, 1:helike.x, 2:helike.z, 3:hlike.lya1, 6:hlike.lya1, 7:helike.z, 8:helike.x, 9:hlike.lya1
# Loaded moments data: mom shape=(3, 417, 96), err shape=(3, 417, 96), pos shape=(96, 4)
# Extracted tau shape=(417,), rhotang shape=(417, 96)
# Computed emiss shape=(417, 96), emisserr shape=(417, 96), v shape=(417, 96), verr shape=(417, 96), ti shape=(417, 96), tierr shape=(417, 96)
# Geom stats: finite=20016/40032, non-unity=20016, range=[7.295e-01, 8.843e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 167 out of 417 total
# Loaded moments data: mom shape=(3, 417, 96), err shape=(3, 417, 96), pos shape=(96, 4)
# Extracted tau shape=(417,), rhotang shape=(417, 96)
# Computed emiss shape=(417, 96), emisserr shape=(417, 96), v shape=(417, 96), verr shape=(417, 96), ti shape=(417, 96), tierr shape=(417, 96)
# Geom stats: finite=20016/40032, non-unity=20016, range=[7.794e-01, 9.554e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 167 out of 417 total
# Loaded moments data: mom shape=(3, 417, 96), err shape=(3, 417, 96), pos shape=(96, 4)
# Extracted tau shape=(417,), rhotang shape=(417, 96)
# Computed emiss shape=(417, 96), emisserr shape=(417, 96), v shape=(417, 96), verr shape=(417, 96), ti shape=(417, 96), tierr shape=(417, 96)
# Geom stats: finite=20016/40032, non-unity=20016, range=[8.804e-01, 1.110e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 167 out of 417 total
# Loaded moments data: mom shape=(3, 417, 32), err shape=(3, 417, 32), pos shape=(32, 4)
# Extracted tau shape=(417,), rhotang shape=(417, 32)
# Computed emiss shape=(417, 32), emisserr shape=(417, 32), v shape=(417, 32), verr shape=(417, 32), ti shape=(417, 32), tierr shape=(417, 32)
# Geom stats: finite=13344/13344, non-unity=13344, range=[8.224e-01, 8.329e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 167 out of 417 total
# Loaded moments data: mom shape=(3, 417, 32), err shape=(3, 417, 32), pos shape=(32, 4)
# Extracted tau shape=(417,), rhotang shape=(417, 32)
# Computed emiss shape=(417, 32), emisserr shape=(417, 32), v shape=(417, 32), verr shape=(417, 32), ti shape=(417, 32), tierr shape=(417, 32)
# Geom stats: finite=13344/13344, non-unity=13344, range=[8.224e-01, 8.329e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 167 out of 417 total
# Loaded moments data: mom shape=(3, 417, 96), err shape=(3, 417, 96), pos shape=(96, 4)
# Extracted tau shape=(417,), rhotang shape=(417, 96)
# Computed emiss shape=(417, 96), emisserr shape=(417, 96), v shape=(417, 96), verr shape=(417, 96), ti shape=(417, 96), tierr shape=(417, 96)
# Geom stats: finite=20016/40032, non-unity=20016, range=[8.804e-01, 1.110e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 167 out of 417 total
# Loaded moments data: mom shape=(3, 417, 96), err shape=(3, 417, 96), pos shape=(96, 4)
# Extracted tau shape=(417,), rhotang shape=(417, 96)
# Computed emiss shape=(417, 96), emisserr shape=(417, 96), v shape=(417, 96), verr shape=(417, 96), ti shape=(417, 96), tierr shape=(417, 96)
# Geom stats: finite=20016/40032, non-unity=20016, range=[7.794e-01, 9.554e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 167 out of 417 total
# Loaded moments data: mom shape=(3, 417, 32), err shape=(3, 417, 32), pos shape=(32, 4)
# Extracted tau shape=(417,), rhotang shape=(417, 32)
# Computed emiss shape=(417, 32), emisserr shape=(417, 32), v shape=(417, 32), verr shape=(417, 32), ti shape=(417, 32), tierr shape=(417, 32)
# Geom stats: finite=13344/13344, non-unity=13344, range=[8.224e-01, 8.329e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 167 out of 417 total
#   lint    1101014019  0:helike.w, 1:helike.x, 2:helike.z, 3:hlike.lya1, 6:hlike.lya1, 7:helike.z, 8:helike.x, 9:hlike.lya1
# Loaded moments data: mom shape=(3, 417, 32), err shape=(3, 417, 32), pos shape=(32, 4)
# Extracted tau shape=(417,), rhotang shape=(417, 32)
# Computed emiss shape=(417, 32), emisserr shape=(417, 32), v shape=(417, 32), verr shape=(417, 32), ti shape=(417, 32), tierr shape=(417, 32)
# Geom stats: finite=13344/13344, non-unity=13344, range=[8.224e-01, 8.328e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 167 out of 417 total
# Loaded moments data: mom shape=(3, 417, 32), err shape=(3, 417, 32), pos shape=(32, 4)
# Extracted tau shape=(417,), rhotang shape=(417, 32)
# Computed emiss shape=(417, 32), emisserr shape=(417, 32), v shape=(417, 32), verr shape=(417, 32), ti shape=(417, 32), tierr shape=(417, 32)
# Geom stats: finite=13344/13344, non-unity=13344, range=[8.224e-01, 8.328e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 167 out of 417 total
# Loaded moments data: mom shape=(3, 417, 32), err shape=(3, 417, 32), pos shape=(32, 4)
# Extracted tau shape=(417,), rhotang shape=(417, 32)
# Computed emiss shape=(417, 32), emisserr shape=(417, 32), v shape=(417, 32), verr shape=(417, 32), ti shape=(417, 32), tierr shape=(417, 32)
# Geom stats: finite=13344/13344, non-unity=13344, range=[8.224e-01, 8.328e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 167 out of 417 total
#   lint    1101014029  3:hlike.lya1, 6:hlike.lya1, 9:hlike.lya1
# Loaded moments data: mom shape=(3, 417, 32), err shape=(3, 417, 32), pos shape=(32, 4)
# Extracted tau shape=(417,), rhotang shape=(417, 32)
# Computed emiss shape=(417, 32), emisserr shape=(417, 32), v shape=(417, 32), verr shape=(417, 32), ti shape=(417, 32), tierr shape=(417, 32)
# Geom stats: finite=13344/13344, non-unity=13344, range=[8.224e-01, 8.328e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 167 out of 417 total
# Loaded moments data: mom shape=(3, 417, 32), err shape=(3, 417, 32), pos shape=(32, 4)
# Extracted tau shape=(417,), rhotang shape=(417, 32)
# Computed emiss shape=(417, 32), emisserr shape=(417, 32), v shape=(417, 32), verr shape=(417, 32), ti shape=(417, 32), tierr shape=(417, 32)
# Geom stats: finite=13344/13344, non-unity=13344, range=[8.224e-01, 8.328e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 167 out of 417 total
# Loaded moments data: mom shape=(3, 417, 32), err shape=(3, 417, 32), pos shape=(32, 4)
# Extracted tau shape=(417,), rhotang shape=(417, 32)
# Computed emiss shape=(417, 32), emisserr shape=(417, 32), v shape=(417, 32), verr shape=(417, 32), ti shape=(417, 32), tierr shape=(417, 32)
# Geom stats: finite=13344/13344, non-unity=13344, range=[8.224e-01, 8.328e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 167 out of 417 total
#   lint    1101014030  3:hlike.lya1, 6:hlike.lya1, 9:hlike.lya1
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.314e-01, 8.833e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.817e-01, 9.568e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=5000/12000, non-unity=5000, range=[8.836e-01, 1.087e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 51 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=5000/12000, non-unity=5000, range=[8.836e-01, 1.087e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 51 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.817e-01, 9.568e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
#   lint    1110114009  0:helike.w, 1:helike.x, 2:helike.z, 7:helike.z, 8:helike.x
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.314e-01, 8.833e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 29 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.817e-01, 9.568e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 29 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=5000/12000, non-unity=5000, range=[8.836e-01, 1.087e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 51 out of 125 total
# Loaded moments data: mom shape=(3, 125, 32), err shape=(3, 125, 32), pos shape=(32, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 32)
# Computed emiss shape=(125, 32), emisserr shape=(125, 32), v shape=(125, 32), verr shape=(125, 32), ti shape=(125, 32), tierr shape=(125, 32)
# Geom stats: finite=2000/4000, non-unity=2000, range=[1.003e+00, 1.012e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 29 out of 125 total
# Loaded moments data: mom shape=(3, 125, 32), err shape=(3, 125, 32), pos shape=(32, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 32)
# Computed emiss shape=(125, 32), emisserr shape=(125, 32), v shape=(125, 32), verr shape=(125, 32), ti shape=(125, 32), tierr shape=(125, 32)
# Geom stats: finite=2000/4000, non-unity=2000, range=[1.003e+00, 1.012e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 29 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=5000/12000, non-unity=5000, range=[8.836e-01, 1.087e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 51 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.817e-01, 9.568e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 29 out of 125 total
# Loaded moments data: mom shape=(3, 125, 32), err shape=(3, 125, 32), pos shape=(32, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 32)
# Computed emiss shape=(125, 32), emisserr shape=(125, 32), v shape=(125, 32), verr shape=(125, 32), ti shape=(125, 32), tierr shape=(125, 32)
# Geom stats: finite=2000/4000, non-unity=2000, range=[1.003e+00, 1.012e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 29 out of 125 total
#   lint    1110114010  0:helike.w, 1:helike.x, 2:helike.z, 3:hlike.lya1, 6:hlike.lya1, 7:helike.z, 8:helike.x, 9:hlike.lya1
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.314e-01, 8.833e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.817e-01, 9.568e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=5000/12000, non-unity=5000, range=[8.836e-01, 1.087e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 51 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=5000/12000, non-unity=5000, range=[8.836e-01, 1.087e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 51 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.817e-01, 9.568e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
#   lint    1110114014  0:helike.w, 1:helike.x, 2:helike.z, 7:helike.z, 8:helike.x
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.314e-01, 8.833e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.817e-01, 9.568e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=5000/12000, non-unity=5000, range=[8.836e-01, 1.087e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 51 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=5000/12000, non-unity=5000, range=[8.836e-01, 1.087e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 51 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.817e-01, 9.568e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
#   lint    1110114014  0:helike.w, 1:helike.x, 2:helike.z, 7:helike.z, 8:helike.x
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.314e-01, 8.833e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.817e-01, 9.568e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=5000/12000, non-unity=5000, range=[8.836e-01, 1.087e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 51 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=5000/12000, non-unity=5000, range=[8.836e-01, 1.087e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 51 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.817e-01, 9.568e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
#   lint    1110114018  0:helike.w, 1:helike.x, 2:helike.z, 7:helike.z, 8:helike.x
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.314e-01, 8.833e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.817e-01, 9.568e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=5000/12000, non-unity=5000, range=[8.836e-01, 1.087e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 51 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=5000/12000, non-unity=5000, range=[8.836e-01, 1.087e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 51 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.817e-01, 9.568e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
#   lint    1110114019  0:helike.w, 1:helike.x, 2:helike.z, 7:helike.z, 8:helike.x
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.314e-01, 8.833e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.817e-01, 9.568e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=5000/12000, non-unity=5000, range=[8.836e-01, 1.087e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 51 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=5000/12000, non-unity=5000, range=[8.836e-01, 1.087e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 51 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.817e-01, 9.568e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
#   lint    1110114020  0:helike.w, 1:helike.x, 2:helike.z, 7:helike.z, 8:helike.x
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.314e-01, 8.833e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.817e-01, 9.568e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=5000/12000, non-unity=5000, range=[8.836e-01, 1.087e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 51 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=5000/12000, non-unity=5000, range=[8.836e-01, 1.087e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 51 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.817e-01, 9.568e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
#   lint    1110114020  0:helike.w, 1:helike.x, 2:helike.z, 7:helike.z, 8:helike.x
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.314e-01, 8.833e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.817e-01, 9.568e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=5000/12000, non-unity=5000, range=[8.836e-01, 1.087e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 51 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=5000/12000, non-unity=5000, range=[8.836e-01, 1.087e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 51 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.817e-01, 9.568e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
#   lint    1110114021  0:helike.w, 1:helike.x, 2:helike.z, 7:helike.z, 8:helike.x
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.314e-01, 8.833e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.817e-01, 9.568e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=5000/12000, non-unity=5000, range=[8.836e-01, 1.087e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 51 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=5000/12000, non-unity=5000, range=[8.836e-01, 1.087e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 51 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.817e-01, 9.568e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
#   lint    1110114021  0:helike.w, 1:helike.x, 2:helike.z, 7:helike.z, 8:helike.x
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.314e-01, 8.833e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.817e-01, 9.568e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=5000/12000, non-unity=5000, range=[8.836e-01, 1.087e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 51 out of 125 total
# Loaded moments data: mom shape=(3, 125, 32), err shape=(3, 125, 32), pos shape=(32, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 32)
# Computed emiss shape=(125, 32), emisserr shape=(125, 32), v shape=(125, 32), verr shape=(125, 32), ti shape=(125, 32), tierr shape=(125, 32)
# Geom stats: finite=2000/4000, non-unity=2000, range=[1.005e+00, 1.018e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 51 out of 125 total
# Loaded moments data: mom shape=(3, 125, 32), err shape=(3, 125, 32), pos shape=(32, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 32)
# Computed emiss shape=(125, 32), emisserr shape=(125, 32), v shape=(125, 32), verr shape=(125, 32), ti shape=(125, 32), tierr shape=(125, 32)
# Geom stats: finite=2000/4000, non-unity=2000, range=[1.005e+00, 1.018e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 51 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=5000/12000, non-unity=5000, range=[8.836e-01, 1.087e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 51 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.817e-01, 9.568e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
# Loaded moments data: mom shape=(3, 125, 32), err shape=(3, 125, 32), pos shape=(32, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 32)
# Computed emiss shape=(125, 32), emisserr shape=(125, 32), v shape=(125, 32), verr shape=(125, 32), ti shape=(125, 32), tierr shape=(125, 32)
# Geom stats: finite=2000/4000, non-unity=2000, range=[1.005e+00, 1.018e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 51 out of 125 total
#   lint    1110114032  0:helike.w, 1:helike.x, 2:helike.z, 3:hlike.lya1, 6:hlike.lya1, 7:helike.z, 8:helike.x, 9:hlike.lya1
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.314e-01, 8.833e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.817e-01, 9.568e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=5000/12000, non-unity=5000, range=[8.836e-01, 1.087e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 51 out of 125 total
# Loaded moments data: mom shape=(3, 125, 32), err shape=(3, 125, 32), pos shape=(32, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 32)
# Computed emiss shape=(125, 32), emisserr shape=(125, 32), v shape=(125, 32), verr shape=(125, 32), ti shape=(125, 32), tierr shape=(125, 32)
# Geom stats: finite=2000/4000, non-unity=2000, range=[1.005e+00, 1.018e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 51 out of 125 total
# Loaded moments data: mom shape=(3, 125, 32), err shape=(3, 125, 32), pos shape=(32, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 32)
# Computed emiss shape=(125, 32), emisserr shape=(125, 32), v shape=(125, 32), verr shape=(125, 32), ti shape=(125, 32), tierr shape=(125, 32)
# Geom stats: finite=2000/4000, non-unity=2000, range=[1.005e+00, 1.018e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 51 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=5000/12000, non-unity=5000, range=[8.836e-01, 1.087e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 51 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.817e-01, 9.568e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
# Loaded moments data: mom shape=(3, 125, 32), err shape=(3, 125, 32), pos shape=(32, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 32)
# Computed emiss shape=(125, 32), emisserr shape=(125, 32), v shape=(125, 32), verr shape=(125, 32), ti shape=(125, 32), tierr shape=(125, 32)
# Geom stats: finite=2000/4000, non-unity=2000, range=[1.005e+00, 1.018e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 51 out of 125 total
#   lint    1110114032  0:helike.w, 1:helike.x, 2:helike.z, 3:hlike.lya1, 6:hlike.lya1, 7:helike.z, 8:helike.x, 9:hlike.lya1
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.309e-01, 8.764e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.813e-01, 9.488e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[9.863e-01, 1.247e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
# Loaded moments data: mom shape=(3, 125, 32), err shape=(3, 125, 32), pos shape=(32, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 32)
# Computed emiss shape=(125, 32), emisserr shape=(125, 32), v shape=(125, 32), verr shape=(125, 32), ti shape=(125, 32), tierr shape=(125, 32)
# Geom stats: finite=2000/4000, non-unity=2000, range=[1.003e+00, 1.012e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
# Loaded moments data: mom shape=(3, 125, 32), err shape=(3, 125, 32), pos shape=(32, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 32)
# Computed emiss shape=(125, 32), emisserr shape=(125, 32), v shape=(125, 32), verr shape=(125, 32), ti shape=(125, 32), tierr shape=(125, 32)
# Geom stats: finite=2000/4000, non-unity=2000, range=[1.043e+00, 1.058e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
# Loaded moments data: mom shape=(3, 125, 32), err shape=(3, 125, 32), pos shape=(32, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 32)
# Computed emiss shape=(125, 32), emisserr shape=(125, 32), v shape=(125, 32), verr shape=(125, 32), ti shape=(125, 32), tierr shape=(125, 32)
# Geom stats: finite=2000/4000, non-unity=2000, range=[1.003e+00, 1.012e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[9.863e-01, 1.247e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.813e-01, 9.488e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
# Loaded moments data: mom shape=(3, 125, 32), err shape=(3, 125, 32), pos shape=(32, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 32)
# Computed emiss shape=(125, 32), emisserr shape=(125, 32), v shape=(125, 32), verr shape=(125, 32), ti shape=(125, 32), tierr shape=(125, 32)
# Geom stats: finite=2000/4000, non-unity=2000, range=[1.003e+00, 1.012e+00]
# Moment source: mom/err
# ...
# Loaded moments data: mom shape=(3, 250, 96), err shape=(3, 250, 96), pos shape=(96, 4)
# Extracted tau shape=(250,), rhotang shape=(250, 96)
# Computed emiss shape=(250, 96), emisserr shape=(250, 96), v shape=(250, 96), verr shape=(250, 96), ti shape=(250, 96), tierr shape=(250, 96)
# Geom stats: finite=12000/24000, non-unity=12000, range=[7.864e-01, 9.533e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 120 out of 250 total
# Loaded moments data: mom shape=(3, 250, 96), err shape=(3, 250, 96), pos shape=(96, 4)
# Extracted tau shape=(250,), rhotang shape=(250, 96)
# Computed emiss shape=(250, 96), emisserr shape=(250, 96), v shape=(250, 96), verr shape=(250, 96), ti shape=(250, 96), tierr shape=(250, 96)
# Geom stats: finite=8750/24000, non-unity=8750, range=[8.822e-01, 1.038e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 26 out of 250 total
# Loaded moments data: mom shape=(3, 250, 32), err shape=(3, 250, 32), pos shape=(32, 4)
# Extracted tau shape=(250,), rhotang shape=(250, 32)
# Computed emiss shape=(250, 32), emisserr shape=(250, 32), v shape=(250, 32), verr shape=(250, 32), ti shape=(250, 32), tierr shape=(250, 32)
# Geom stats: finite=3750/8000, non-unity=3750, range=[8.671e-01, 8.779e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 26 out of 250 total
# Loaded moments data: mom shape=(3, 250, 32), err shape=(3, 250, 32), pos shape=(32, 4)
# Extracted tau shape=(250,), rhotang shape=(250, 32)
# Computed emiss shape=(250, 32), emisserr shape=(250, 32), v shape=(250, 32), verr shape=(250, 32), ti shape=(250, 32), tierr shape=(250, 32)
# Geom stats: finite=3750/8000, non-unity=3750, range=[8.671e-01, 8.779e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 26 out of 250 total
# Loaded moments data: mom shape=(3, 250, 96), err shape=(3, 250, 96), pos shape=(96, 4)
# Extracted tau shape=(250,), rhotang shape=(250, 96)
# Computed emiss shape=(250, 96), emisserr shape=(250, 96), v shape=(250, 96), verr shape=(250, 96), ti shape=(250, 96), tierr shape=(250, 96)
# Geom stats: finite=8750/24000, non-unity=8750, range=[8.822e-01, 1.038e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 26 out of 250 total
# Loaded moments data: mom shape=(3, 250, 96), err shape=(3, 250, 96), pos shape=(96, 4)
# Extracted tau shape=(250,), rhotang shape=(250, 96)
# Computed emiss shape=(250, 96), emisserr shape=(250, 96), v shape=(250, 96), verr shape=(250, 96), ti shape=(250, 96), tierr shape=(250, 96)
# Geom stats: finite=12000/24000, non-unity=12000, range=[7.864e-01, 9.533e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 120 out of 250 total
# Loaded moments data: mom shape=(3, 250, 32), err shape=(3, 250, 32), pos shape=(32, 4)
# Extracted tau shape=(250,), rhotang shape=(250, 32)
# Computed emiss shape=(250, 32), emisserr shape=(250, 32), v shape=(250, 32), verr shape=(250, 32), ti shape=(250, 32), tierr shape=(250, 32)
# Geom stats: finite=3750/8000, non-unity=3750, range=[8.671e-01, 8.779e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 26 out of 250 total
#   lint    1160721019  0:helike.w, 1:helike.x, 2:helike.z, 3:hlike.lya1, 6:hlike.lya1, 7:helike.z, 8:helike.x, 9:hlike.lya1
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.361e-01, 8.816e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.864e-01, 9.533e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=4375/12000, non-unity=4375, range=[8.823e-01, 1.038e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 26 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=4375/12000, non-unity=4375, range=[8.823e-01, 1.038e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 26 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.864e-01, 9.533e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
#   lint    1160729005  0:helike.w, 1:helike.x, 2:helike.z, 7:helike.z, 8:helike.x
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.361e-01, 8.816e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.864e-01, 9.533e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=4375/12000, non-unity=4375, range=[8.823e-01, 1.100e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 17 out of 125 total
# Loaded moments data: mom shape=(3, 125, 32), err shape=(3, 125, 32), pos shape=(32, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 32)
# Computed emiss shape=(125, 32), emisserr shape=(125, 32), v shape=(125, 32), verr shape=(125, 32), ti shape=(125, 32), tierr shape=(125, 32)
# Geom stats: finite=1500/4000, non-unity=1500, range=[8.669e-01, 8.738e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 17 out of 125 total
# Loaded moments data: mom shape=(3, 125, 32), err shape=(3, 125, 32), pos shape=(32, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 32)
# Computed emiss shape=(125, 32), emisserr shape=(125, 32), v shape=(125, 32), verr shape=(125, 32), ti shape=(125, 32), tierr shape=(125, 32)
# Geom stats: finite=1500/4000, non-unity=1500, range=[8.669e-01, 8.738e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 17 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=4375/12000, non-unity=4375, range=[8.823e-01, 1.100e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 17 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=6000/12000, non-unity=6000, range=[7.864e-01, 9.533e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 60 out of 125 total
# Loaded moments data: mom shape=(3, 125, 32), err shape=(3, 125, 32), pos shape=(32, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 32)
# Computed emiss shape=(125, 32), emisserr shape=(125, 32), v shape=(125, 32), verr shape=(125, 32), ti shape=(125, 32), tierr shape=(125, 32)
# Geom stats: finite=1500/4000, non-unity=1500, range=[8.669e-01, 8.738e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 17 out of 125 total
#   lint    1160729008  0:helike.w, 1:helike.x, 2:helike.z, 3:hlike.lya1, 6:hlike.lya1, 7:helike.z, 8:helike.x, 9:hlike.lya1
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=4125/12000, non-unity=4125, range=[8.824e-01, 1.031e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 51 out of 125 total
# Loaded moments data: mom shape=(3, 125, 32), err shape=(3, 125, 32), pos shape=(32, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 32)
# Computed emiss shape=(125, 32), emisserr shape=(125, 32), v shape=(125, 32), verr shape=(125, 32), ti shape=(125, 32), tierr shape=(125, 32)
# Geom stats: finite=3000/4000, non-unity=3000, range=[8.668e-01, 8.806e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 51 out of 125 total
# Loaded moments data: mom shape=(3, 125, 32), err shape=(3, 125, 32), pos shape=(32, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 32)
# Computed emiss shape=(125, 32), emisserr shape=(125, 32), v shape=(125, 32), verr shape=(125, 32), ti shape=(125, 32), tierr shape=(125, 32)
# Geom stats: finite=3000/4000, non-unity=3000, range=[8.668e-01, 8.806e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 51 out of 125 total
# Loaded moments data: mom shape=(3, 125, 96), err shape=(3, 125, 96), pos shape=(96, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 96)
# Computed emiss shape=(125, 96), emisserr shape=(125, 96), v shape=(125, 96), verr shape=(125, 96), ti shape=(125, 96), tierr shape=(125, 96)
# Geom stats: finite=4125/12000, non-unity=4125, range=[8.824e-01, 1.031e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 51 out of 125 total
# Loaded moments data: mom shape=(3, 125, 32), err shape=(3, 125, 32), pos shape=(32, 4)
# Extracted tau shape=(125,), rhotang shape=(125, 32)
# Computed emiss shape=(125, 32), emisserr shape=(125, 32), v shape=(125, 32), verr shape=(125, 32), ti shape=(125, 32), tierr shape=(125, 32)
# Geom stats: finite=3000/4000, non-unity=3000, range=[8.668e-01, 8.806e-01]
# Moment source: mom/err
# Number of valid time points (tau != -1): 51 out of 125 total
#   lint    1160922007  2:helike.z, 3:hlike.lya1, 6:hlike.lya1, 7:helike.z, 9:hlike.lya1
#   lint    1220221008  (none)
#   lint    1220221009  (none)
#   lint    1220221010  (none)
#   lint    1220221011  (none)
#   lint    1220221012  (none)
# profile   1080312014  (none)
# profile   1080502015  (none)
# profile   1080522007  (none)
# profile   1100305019  3:hlike.lya1, 6:hlike.lya1, 9:hlike.lya1
# profile   1101014006  0:helike.w, 1:helike.x, 2:helike.z, 7:helike.z, 8:helike.x
# profile   1101014019  0:helike.w, 1:helike.x, 2:helike.z, 7:helike.z, 8:helike.x
# profile   1101014029  3:hlike.lya1, 6:hlike.lya1, 9:hlike.lya1
# profile   1101014030  3:hlike.lya1, 6:hlike.lya1, 9:hlike.lya1
# profile   1110114009  0:helike.w, 1:helike.x, 2:helike.z, 7:helike.z, 8:helike.x
# profile   1110114010  0:helike.w, 1:helike.x, 2:helike.z, 3:hlike.lya1, 6:hlike.lya1, 7:helike.z, 8:helike.x, 9:hlike.lya1
# profile   1110114014  0:helike.w, 1:helike.x, 2:helike.z, 7:helike.z, 8:helike.x
# profile   1110114014  0:helike.w, 1:helike.x, 2:helike.z, 7:helike.z, 8:helike.x
# profile   1110114018  0:helike.w, 1:helike.x, 2:helike.z, 7:helike.z, 8:helike.x
# profile   1110114019  0:helike.w, 1:helike.x, 2:helike.z, 7:helike.z, 8:helike.x
# profile   1110114020  0:helike.w, 1:helike.x, 2:helike.z, 7:helike.z, 8:helike.x
# profile   1110114020  0:helike.w, 1:helike.x, 2:helike.z, 7:helike.z, 8:helike.x
# profile   1110114021  0:helike.w, 1:helike.x, 2:helike.z, 7:helike.z, 8:helike.x
# profile   1110114021  0:helike.w, 1:helike.x, 2:helike.z, 7:helike.z, 8:helike.x
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 28
#      24 shots_list = np.sort( np.loadtxt(f'{file_name}.csv', dtype=int, delimiter=',').flatten() ).tolist()
#      25 print(shots_list)
#      26 # Example: scan with default quality gates (5 timepoints, 5 channels, no error threshold)
#      27 lint_results = scan_lint_quality(shots_list, min_timepoints=5, min_channels=5)
# ---> 28 prof_results = scan_profile_quality(shots_list, min_timepoints=5, min_channels=5)
#      29
#      30 with open(f"hirexsr_{file_name}_lint_quality.json", "w") as f:
#      31     json.dump(_build_output_dict(lint_results), f, indent=4, sort_keys=True, ensure_ascii=False)
#
# File /mnt/home/rianc/Documents/HIREXSR_py/hirexsr_data_quality.py:393, in scan_profile_quality(shots, tht, quiet, min_timepoints, min_channels, max_verr_abs, max_verr_rel, max_tierr_abs, max_tierr_rel)
#     391 for line_idx in range(10):
#     392     try:
# --> 393         out = hirexsr_get_profile_py(
#     394             shot=int(shot),
#     395             line=line_idx,
#     396             quiet=True,
#     397             dc_shift=0.0,
#     398             tht=tht,
#     399             override=False,
#     400             seltime=None,
#     401         )
#     402         ok = quality_check_profile(
#     403             out,
#     404             min_timepoints=min_timepoints,
#    (...)    409             max_tierr_rel=max_tierr_rel,
#     410         )
#     411         if ok:
#
# File /mnt/home/rianc/Documents/HIREXSR_py/hirexsr_get_profile_py.py:268, in hirexsr_get_profile_py(shot, line, quiet, dc_shift, tht, override, seltime)
#     254     raise ValueError(f"Unexpected psinorm shape {psinorm.shape}")
#     256 emiss, emisserr, omg, omgerr, ti, tierr, subtime, subpsinorm = _slice_seltime(
#     257     emiss=emiss,
#     258     emisserr=emisserr,
#    (...)    265     seltime=seltime,
#     266 )
# --> 268 conn_a = openTree(shot, "analysis")
#     269 try:
#     270     rmid = np.asarray(conn_a.get(r"\ANALYSIS::EFIT_RMID").data())
#
# File /mnt/home/rianc/Documents/HIREXSR_py/hirexsr_lint_profile_py.py:99, in openTree(shotno, treeName)
#      98 def openTree(shotno: int, treeName: str = "CMOD"):
# ---> 99     conn = mds.Connection("alcdata")
#     100     conn.openTree(treeName, shotno)
#     101     return conn
#
# File ~/Documents/HIREXSR_py/.venv/lib/python3.12/site-packages/mdsthin/connection.py:149, in Connection.__init__(self, url, timeout, verbose, ssh_backend, ssh_port, sshp_host, ssh_subprocess_args, ssh_paramiko_options, ssh_use_plink)
#     146 else:
#     147     # The MDSip default port
#     148     self._port = 8000
# --> 149 self.connect()
#
# File ~/Documents/HIREXSR_py/.venv/lib/python3.12/site-packages/mdsthin/connection.py:391, in Connection.connect(self)
#     389 msg_login_view = memoryview(msg_login_buffer)
#     390 while len(msg_login_view) > 0:
# --> 391     bytes_read = self._socket.recv_into(msg_login_view, len(msg_login_view), 0)
#     392     msg_login_view = msg_login_view[bytes_read : ]
#     394 msg_login = Message.from_buffer_copy(msg_login_buffer)
#
# KeyboardInterrupt:

# %%
from hirexsr_lint_profile_py import hirexsr_get_lint_profile_py

shot = 1121001018
line = 2
result = hirexsr_get_lint_profile_py(
        shot=shot,
        line=line,
        tht=0,
        use_idl_profile_moments=False,
        debug_velocity_checks=False,
    )


_plot_lint_profile(result, every_nth=1, x_axis='rhotang', doSave='../output_plots/')
# Out:
# Loaded moments data: mom shape=(3, 417, 96), err shape=(3, 417, 96), pos shape=(96, 4)
# Extracted tau shape=(417,), rhotang shape=(417, 96)
# Computed emiss shape=(417, 96), emisserr shape=(417, 96), v shape=(417, 96), verr shape=(417, 96), ti shape=(417, 96), tierr shape=(417, 96)
# Geom stats: finite=20016/40032, non-unity=20016, range=[8.666e-01, 1.079e+00]
# Moment source: mom/err
# Number of valid time points (tau != -1): 11 out of 417 total
# /mnt/home/rianc/Documents/HIREXSR_py/hirexsr_plotting_py.py:437: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 14
#      10         debug_velocity_checks=False,
#      11     )
#      12
#      13
# ---> 14 _plot_lint_profile(result, every_nth=1, x_axis='rhotang', doSave='../output_plots/')
#
# File /mnt/home/rianc/Documents/HIREXSR_py/hirexsr_plotting_py.py:440, in _plot_lint_profile(out, every_nth, x_axis, specific_timepoint, w_lim, ti_lim, emiss_lim, doSave)
#     437 plt.tight_layout()
#     439 if doSave:
# --> 440     fig.savefig(
#     441         f"{doSave}lint_profile_shot{out.shot}_line{out.line}_tht{out.tht}_{x_axis}.pdf",
#     442         transparent=True,
#     443     )
#     444     print(
#     445         f"Saved plot to {doSave}lint_profile_shot{out.shot}_line{out.line}_tht{out.tht}_{x_axis}.pdf"
#     446     )
#     448 plt.show(block=True if "ipykernel" not in sys.modules else False)
#
# File ~/Documents/HIREXSR_py/.venv/lib/python3.12/site-packages/matplotlib/figure.py:3490, in Figure.savefig(self, fname, transparent, **kwargs)
#    3488     for ax in self.axes:
#    3489         _recursively_make_axes_transparent(stack, ax)
# -> 3490 self.canvas.print_figure(fname, **kwargs)
#
# File ~/Documents/HIREXSR_py/.venv/lib/python3.12/site-packages/matplotlib/backend_bases.py:2186, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2182 try:
#    2183     # _get_renderer may change the figure dpi (as vector formats
#    2184     # force the figure dpi to 72), so we need to set it again here.
#    2185     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2186         result = print_method(
#    2187             filename,
#    2188             facecolor=facecolor,
#    2189             edgecolor=edgecolor,
#    2190             orientation=orientation,
#    2191             bbox_inches_restore=_bbox_inches_restore,
#    2192             **kwargs)
#    2193 finally:
#    2194     if bbox_inches and restore_bbox:
#
# File ~/Documents/HIREXSR_py/.venv/lib/python3.12/site-packages/matplotlib/backend_bases.py:2042, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2038     optional_kws = {  # Passed by print_figure for other renderers.
#    2039         "dpi", "facecolor", "edgecolor", "orientation",
#    2040         "bbox_inches_restore"}
#    2041     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2042     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2043         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2044 else:  # Let third-parties do as they see fit.
#    2045     print_method = meth
#
# File ~/Documents/HIREXSR_py/.venv/lib/python3.12/site-packages/matplotlib/backends/backend_pdf.py:2779, in FigureCanvasPdf.print_pdf(self, filename, bbox_inches_restore, metadata)
#    2777     file = filename._ensure_file()
#    2778 else:
# -> 2779     file = PdfFile(filename, metadata=metadata)
#    2780 try:
#    2781     file.newPage(width, height)
#
# File ~/Documents/HIREXSR_py/.venv/lib/python3.12/site-packages/matplotlib/backends/backend_pdf.py:687, in PdfFile.__init__(self, filename, metadata)
#     685 self.original_file_like = None
#     686 self.tell_base = 0
# --> 687 fh, opened = cbook.to_filehandle(filename, "wb", return_opened=True)
#     688 if not opened:
#     689     try:
#
# File ~/Documents/HIREXSR_py/.venv/lib/python3.12/site-packages/matplotlib/cbook.py:546, in to_filehandle(fname, flag, return_opened, encoding)
#     544         fh = bz2.BZ2File(fname, flag)
#     545     else:
# --> 546         fh = open(fname, flag, encoding=encoding)
#     547     opened = True
#     548 elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: '../output_plots/lint_profile_shot1121001018_line2_tht0_rhotang.pdf'

# %%
from n_i_estimation import estimate_n_i

ni_estimate, te_all, ne_all, r_all, zeff_interpolated, yag_time  = estimate_n_i(shotno=1140221012, doPlot=True)
# Out:
# /mnt/home/rianc/Documents/HIREXSR_py/n_i_estimation.py:62: RuntimeWarning: divide by zero encountered in divide
#   ni_estimate = ne_all / zeff_interpolated  # Simplified estimation
# /mnt/home/rianc/Documents/HIREXSR_py/n_i_estimation.py:62: RuntimeWarning: invalid value encountered in divide
#   ni_estimate = ne_all / zeff_interpolated  # Simplified estimation
# test
# test2

# %%
# Out:
# (25, 250) (25, 250) (25, 250) (250,) (250,)
# (250,) (25,)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 5
#       1 print(ni_estimate.shape, te_all.shape, r_all.shape, zeff_interpolated.shape, yag_time.shape)
#       2 print(yag_time.shape, r_all[:,100].shape)
#       3 import matplotlib.pyplot as plt
#       4 plt.figure()
# ----> 5 plt.contourf( te_all, r_all[:,100], ni_estimate.T, levels=100)
#
# File ~/Documents/HIREXSR_py/.venv/lib/python3.12/site-packages/matplotlib/pyplot.py:3190, in contourf(data, *args, **kwargs)
#    3188 @_copy_docstring_and_deprecators(Axes.contourf)
#    3189 def contourf(*args, data=None, **kwargs) -> QuadContourSet:
# -> 3190     __ret = gca().contourf(
#    3191         *args, **({"data": data} if data is not None else {}), **kwargs
#    3192     )
#    3193     if __ret._A is not None:  # type: ignore[attr-defined]
#    3194         sci(__ret)
#
# File ~/Documents/HIREXSR_py/.venv/lib/python3.12/site-packages/matplotlib/__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File ~/Documents/HIREXSR_py/.venv/lib/python3.12/site-packages/matplotlib/axes/_axes.py:6797, in Axes.contourf(self, *args, **kwargs)
#    6786 """
#    6787 Plot filled contours.
#    6788
#    (...)   6794 %(contour_doc)s
#    6795 """
#    6796 kwargs['filled'] = True
# -> 6797 contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6798 self._request_autoscale_view()
#    6799 return contours
#
# File ~/Documents/HIREXSR_py/.venv/lib/python3.12/site-packages/matplotlib/contour.py:701, in ContourSet.__init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, colorizer, extend, antialiased, nchunk, locator, transform, negative_linestyles, clip_path, *args, **kwargs)
#     697 if self.negative_linestyles is None:
#     698     self.negative_linestyles = \
#     699         mpl.rcParams['contour.negative_linestyle']
# --> 701 kwargs = self._process_args(*args, **kwargs)
#     702 self._process_levels()
#     704 self._extend_min = self.extend in ['min', 'both']
#
# File ~/Documents/HIREXSR_py/.venv/lib/python3.12/site-packages/matplotlib/contour.py:1319, in QuadContourSet._process_args(self, corner_mask, algorithm, *args, **kwargs)
#    1316         corner_mask = mpl.rcParams['contour.corner_mask']
#    1317 self._corner_mask = corner_mask
# -> 1319 x, y, z = self._contour_args(args, kwargs)
#    1321 contour_generator = contourpy.contour_generator(
#    1322     x, y, z, name=self._algorithm, corner_mask=self._corner_mask,
#    1323     line_type=contourpy.LineType.SeparateCode,
#    1324     fill_type=contourpy.FillType.OuterCode,
#    1325     chunk_size=self.nchunk)
#    1327 t = self.get_transform()
#
# File ~/Documents/HIREXSR_py/.venv/lib/python3.12/site-packages/matplotlib/contour.py:1359, in QuadContourSet._contour_args(self, args, kwargs)
#    1357 elif 2 < nargs <= 4:
#    1358     x, y, z_orig, *args = args
# -> 1359     x, y, z = self._check_xyz(x, y, z_orig, kwargs)
#    1361 else:
#    1362     raise _api.nargs_error(fn, takes="from 1 to 4", given=nargs)
#
# File ~/Documents/HIREXSR_py/.venv/lib/python3.12/site-packages/matplotlib/contour.py:1392, in QuadContourSet._check_xyz(self, x, y, z, kwargs)
#    1389 Ny, Nx = z.shape
#    1391 if x.ndim != y.ndim:
# -> 1392     raise TypeError(f"Number of dimensions of x ({x.ndim}) and y "
#    1393                     f"({y.ndim}) do not match")
#    1394 if x.ndim == 1:
#    1395     nx, = x.shape
#
# TypeError: Number of dimensions of x (2) and y (1) do not match
